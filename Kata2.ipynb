# %% [markdown]
# Ejercicio Kata2

# %% [markdown]
# Microsoft Windows [Version 10.0.19043.1466]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\fcgsi>cd..
#
# C:\Users>cd..
#
# C:\>dir
#  Volume in drive C is OS
#  Volume Serial Number is FC7E-54D2
#
#  Directory of C:\
#
# 11/05/2021  12:07 p. m.    <DIR>          $WINDOWS.~BT
# 03/12/2020  10:28 a. m.         6,265,840 aow_drv.log
# 27/12/2019  11:15 a. m.    <DIR>          Brother
# 16/07/2021  01:29 p. m.    <DIR>          Config
# 04/05/2021  09:23 p. m.    <DIR>          DRIVERS
# 19/07/2021  02:12 a. m.    <DIR>          ESD
# 13/08/2019  02:38 a. m.    <DIR>          eSupport
# 07/11/2007  08:00 a. m.            17,734 eula.1028.txt
# 07/11/2007  08:00 a. m.            17,734 eula.1031.txt
# 07/11/2007  08:00 a. m.            10,134 eula.1033.txt
# 07/11/2007  08:00 a. m.            17,734 eula.1036.txt
# 07/11/2007  08:00 a. m.            17,734 eula.1040.txt
# 07/11/2007  08:00 a. m.               118 eula.1041.txt
# 07/11/2007  08:00 a. m.            17,734 eula.1042.txt
# 07/11/2007  08:00 a. m.            17,734 eula.2052.txt
# 07/11/2007  08:00 a. m.            17,734 eula.3082.txt
# 07/11/2007  08:00 a. m.             1,110 globdata.ini
# 07/11/2007  08:03 a. m.           562,688 install.exe
# 07/11/2007  08:00 a. m.               843 install.ini
# 07/11/2007  08:03 a. m.            76,304 install.res.1028.dll
# 07/11/2007  08:03 a. m.            96,272 install.res.1031.dll
# 07/11/2007  08:03 a. m.            91,152 install.res.1033.dll
# 07/11/2007  08:03 a. m.            97,296 install.res.1036.dll
# 07/11/2007  08:03 a. m.            95,248 install.res.1040.dll
# 07/11/2007  08:03 a. m.            81,424 install.res.1041.dll
# 07/11/2007  08:03 a. m.            79,888 install.res.1042.dll
# 07/11/2007  08:03 a. m.            75,792 install.res.2052.dll
# 07/11/2007  08:03 a. m.            96,272 install.res.3082.dll
# 25/11/2020  08:07 p. m.    <DIR>          LDPlayer
# 05/05/2021  10:46 p. m.    <DIR>          Microsoft
# 21/10/2021  02:50 p. m.               276 NvContainerRecoveryNVDisplay.ContainerLocalSystem.reg
# 07/12/2019  03:14 a. m.    <DIR>          PerfLogs
# 30/01/2022  10:48 p. m.    <DIR>          Program Files
# 06/02/2022  12:38 p. m.    <DIR>          Program Files (x86)
# 01/12/2020  10:18 p. m.    <DIR>          Temp
# 30/07/2021  01:34 a. m.    <DIR>          Users
# 07/11/2007  08:00 a. m.             5,686 vcredist.bmp
# 07/11/2007  08:09 a. m.         1,442,522 VC_RED.cab
# 07/11/2007  08:12 a. m.           232,960 VC_RED.MSI
# 18/12/2021  12:01 a. m.    <DIR>          Windows
#               26 File(s)      9,435,963 bytes
#               14 Dir(s)  104,104,050,688 bytes free
#
#
# C:\>python3 -m venv env
#
# C:\>cd env
#
# C:\env>dir
#  Volume in drive C is OS
#  Volume Serial Number is FC7E-54D2
#
#  Directory of C:\env
#
# 11/02/2022  08:17 p. m.    <DIR>          .
# 11/02/2022  08:17 p. m.    <DIR>          ..
# 11/02/2022  08:17 p. m.    <DIR>          Include
# 11/02/2022  08:17 p. m.    <DIR>          Lib
# 11/02/2022  08:17 p. m.               166 pyvenv.cfg
# 11/02/2022  08:17 p. m.    <DIR>          Scripts
#                1 File(s)            166 bytes
#                5 Dir(s)  104,075,788,288 bytes free
#
# C:\env>cd..
#
# C:\>source env/bin/activate
# 'source' is not recognized as an internal or external command,
# operable program or batch file.
#
# C:\>env\bin/activate
# 'env\bin' is not recognized as an internal or external command,
# operable program or batch file.
#
# C:\>env\Scripts\activate
#
# (env) C:\>pip freeze
#
# (env) C:\>pip install
# ERROR: You must give at least one requirement to install (see "pip help install")
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\env\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (env) C:\>pip install python-dateutil
# Collecting python-dateutil
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, python-dateutil
# Successfully installed python-dateutil-2.8.2 six-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\env\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (env) C:\>pip freeze
# python-dateutil==2.8.2
# six==1.16.0
#
# (env) C:\>deactivate
# C:\>
